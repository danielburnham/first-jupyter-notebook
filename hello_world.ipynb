% %% [markdown]
% This is simply a test...

% %%
2+2
% Out:
% ans =
%
%      4

% %%
x = linspace(1,10,100);

% %%
y = sin(x);

% %%
plot(x,y,'b-')
hold on
xlabel('x')
ylabel('y')

for i = 1:10
    plot(i,i/10,'o')
end
